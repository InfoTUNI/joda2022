# %% [markdown]
# <h1>Crawlers and Scrapers</h1>
#
# The goal of this session is to build and run our own Amazon.com scraper using the **scrapy** python library.
#
# Our scraper will crawl through a specific product's customer review pages and get all of the available ratings and reviews. This will allow us to get complete review details that we may not be able to get through the Amazon Product Advertising API.
#
# First we will install scrapy using pip command in terminal/cmd:

# %%
# !pip install scrapy
# Out:
# Collecting scrapy
#   Using cached Scrapy-2.6.1-py2.py3-none-any.whl (264 kB)
# Requirement already satisfied: setuptools in /Users/skenderi/miniconda/miniconda3/envs/py38/lib/python3.8/site-packages (from scrapy) (58.0.4)
# Collecting lxml>=3.5.0
#   Downloading lxml-4.8.0-cp38-cp38-macosx_10_14_x86_64.whl (4.5 MB)
#      |████████████████████████████████| 4.5 MB 6.6 MB/s eta 0:00:01
# Requirement already satisfied: pyOpenSSL>=16.2.0 in /Users/skenderi/miniconda/miniconda3/envs/py38/lib/python3.8/site-packages (from scrapy) (22.0.0)
# Collecting tldextract
#   Using cached tldextract-3.2.0-py3-none-any.whl (87 kB)
# Collecting Twisted>=17.9.0
#   Using cached Twisted-22.2.0-py3-none-any.whl (3.1 MB)
# Collecting service-identity>=16.0.0
#   Using cached service_identity-21.1.0-py2.py3-none-any.whl (12 kB)
# Collecting zope.interface>=4.1.3
#   Downloading zope.interface-5.4.0-cp38-cp38-macosx_10_14_x86_64.whl (208 kB)
#      |████████████████████████████████| 208 kB 9.3 MB/s eta 0:00:01
# Collecting PyDispatcher>=2.0.5
#   Using cached PyDispatcher-2.0.5.zip (47 kB)
# Collecting w3lib>=1.17.0
#   Using cached w3lib-1.22.0-py2.py3-none-any.whl (20 kB)
# Collecting queuelib>=1.4.2
#   Using cached queuelib-1.6.2-py2.py3-none-any.whl (13 kB)
# Collecting cssselect>=0.9.1
#   Using cached cssselect-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting itemadapter>=0.1.0
#   Downloading itemadapter-0.5.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: cryptography>=2.0 in /Users/skenderi/miniconda/miniconda3/envs/py38/lib/python3.8/site-packages (from scrapy) (36.0.1)
# Collecting itemloaders>=1.0.1
#   Using cached itemloaders-1.0.4-py3-none-any.whl (11 kB)
# Collecting protego>=0.1.15
#   Using cached Protego-0.2.1-py2.py3-none-any.whl (8.2 kB)
# Collecting parsel>=1.5.0
#   Using cached parsel-1.6.0-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: cffi>=1.12 in /Users/skenderi/miniconda/miniconda3/envs/py38/lib/python3.8/site-packages (from cryptography>=2.0->scrapy) (1.15.0)
# Requirement already satisfied: pycparser in /Users/skenderi/miniconda/miniconda3/envs/py38/lib/python3.8/site-packages (from cffi>=1.12->cryptography>=2.0->scrapy) (2.21)
# Collecting jmespath>=0.9.5
#   Using cached jmespath-1.0.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: six>=1.6.0 in /Users/skenderi/miniconda/miniconda3/envs/py38/lib/python3.8/site-packages (from parsel>=1.5.0->scrapy) (1.16.0)
# Requirement already satisfied: attrs>=19.1.0 in /Users/skenderi/miniconda/miniconda3/envs/py38/lib/python3.8/site-packages (from service-identity>=16.0.0->scrapy) (21.4.0)
# Requirement already satisfied: pyasn1-modules in /Users/skenderi/miniconda/miniconda3/envs/py38/lib/python3.8/site-packages (from service-identity>=16.0.0->scrapy) (0.2.8)
# Requirement already satisfied: pyasn1 in /Users/skenderi/miniconda/miniconda3/envs/py38/lib/python3.8/site-packages (from service-identity>=16.0.0->scrapy) (0.4.8)
# Collecting constantly>=15.1
#   Using cached constantly-15.1.0-py2.py3-none-any.whl (7.9 kB)
# Collecting incremental>=21.3.0
#   Using cached incremental-21.3.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: typing-extensions>=3.6.5 in /Users/skenderi/miniconda/miniconda3/envs/py38/lib/python3.8/site-packages (from Twisted>=17.9.0->scrapy) (4.1.1)
# Collecting hyperlink>=17.1.1
#   Using cached hyperlink-21.0.0-py2.py3-none-any.whl (74 kB)
# Collecting Automat>=0.8.0
#   Using cached Automat-20.2.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: idna>=2.5 in /Users/skenderi/miniconda/miniconda3/envs/py38/lib/python3.8/site-packages (from hyperlink>=17.1.1->Twisted>=17.9.0->scrapy) (3.3)
# Collecting requests-file>=1.4
#   Using cached requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# Requirement already satisfied: requests>=2.1.0 in /Users/skenderi/miniconda/miniconda3/envs/py38/lib/python3.8/site-packages (from tldextract->scrapy) (2.27.1)
# Requirement already satisfied: filelock>=3.0.8 in /Users/skenderi/miniconda/miniconda3/envs/py38/lib/python3.8/site-packages (from tldextract->scrapy) (3.6.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/skenderi/miniconda/miniconda3/envs/py38/lib/python3.8/site-packages (from requests>=2.1.0->tldextract->scrapy) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/skenderi/miniconda/miniconda3/envs/py38/lib/python3.8/site-packages (from requests>=2.1.0->tldextract->scrapy) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/skenderi/miniconda/miniconda3/envs/py38/lib/python3.8/site-packages (from requests>=2.1.0->tldextract->scrapy) (1.26.8)
# Building wheels for collected packages: PyDispatcher
#   Building wheel for PyDispatcher (setup.py) ... done
#   Created wheel for PyDispatcher: filename=PyDispatcher-2.0.5-py3-none-any.whl size=11516 sha256=656c9ed4571a21d7231ce7cebe89e9e8bc7c1e32c4c4ee3e1e53b8362da377db
#   Stored in directory: /Users/skenderi/Library/Caches/pip/wheels/3c/31/7f/d7d7b5f0b9bad841ed856138ff0c5ee2bf2e04dbeb413097c8
# Successfully built PyDispatcher
# Installing collected packages: w3lib, lxml, cssselect, zope.interface, requests-file, parsel, jmespath, itemadapter, incremental, hyperlink, constantly, Automat, Twisted, tldextract, service-identity, queuelib, PyDispatcher, protego, itemloaders, scrapy
# Successfully installed Automat-20.2.0 PyDispatcher-2.0.5 Twisted-22.2.0 constantly-15.1.0 cssselect-1.1.0 hyperlink-21.0.0 incremental-21.3.0 itemadapter-0.5.0 itemloaders-1.0.4 jmespath-1.0.0 lxml-4.8.0 parsel-1.6.0 protego-0.2.1 queuelib-1.6.2 requests-file-1.5.1 scrapy-2.6.1 service-identity-21.1.0 tldextract-3.2.0 w3lib-1.22.0 zope.interface-5.4.0

# %% [markdown]
# Next, we'll use scrapy to automatically generate a skeleton of the code needed for our scraper. (On terminal/cmd type the following command without the exclamation mark):

# %%
# !scrapy genspider amazon_scraper amazon.com
# Out:
# Created spider 'amazon_scraper' using template 'basic'

# %% [markdown]
# A new python-script, amazon_scraper.py file will be created. The final content of our scraper will be as follows:

# %%
# -*- coding: utf-8 -*-
import scrapy

class AmazonScraperSpider(scrapy.Spider):
    name = 'amazon_scraper'
    allowed_domains = ['amazon.com']
    # assing a product-review-page url below
    start_urls = ['https://www.amazon.com/Apple-iPhone-Verizon-Unlocked-Renewed/product-reviews/B07HYDFX8G/ref=cm_cr_arp_d_viewopt_srt?ie=UTF8&reviewerType=all_reviews&sortBy=helpful&pageNumber=1']
    
    def parse(self, response):
        
        review_texts = response.css('.a-size-base.review-text')
        
        for i in range(len(review_texts)):
            review_texts[i] = "".join(review_texts[i].css('::text').extract()).strip()

        review_ratings = response.css('[data-hook="review-star-rating"] > span::text').extract()

        for i in range(len(review_texts)):
            review = {
                'text' : review_texts[i],
                'rating': review_ratings[i]
            }
            yield review

        next_page_url = response.css('.a-last > a::attr(href)').extract_first()
        yield response.follow(next_page_url, self.parse)

# %% [markdown]
# We can call the script from terminal/cmd as follows:

# %%
# !scrapy runspider amazon_scraper.py -o out.json --set=USER_AGENT="Mozilla/5.0 (iPad; CPU OS 12_2 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Mobile/15E148"
# Out:
# 2022-04-07 10:02:05 [scrapy.utils.log] INFO: Scrapy 2.6.1 started (bot: scrapybot)
# 2022-04-07 10:02:05 [scrapy.utils.log] INFO: Versions: lxml 4.8.0.0, libxml2 2.9.12, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 22.2.0, Python 3.8.0 (default, Nov  6 2019, 15:49:01) - [Clang 4.0.1 (tags/RELEASE_401/final)], pyOpenSSL 22.0.0 (OpenSSL 1.1.1m  14 Dec 2021), cryptography 36.0.1, Platform macOS-10.16-x86_64-i386-64bit
# 2022-04-07 10:02:05 [scrapy.crawler] INFO: Overridden settings:
# {'SPIDER_LOADER_WARN_ONLY': True,
#  'USER_AGENT': 'Mozilla/5.0 (iPad; CPU OS 12_2 like Mac OS X) '
#                'AppleWebKit/605.1.15 (KHTML, like Gecko) Mobile/15E148'}
# 2022-04-07 10:02:05 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2022-04-07 10:02:05 [scrapy.extensions.telnet] INFO: Telnet Password: c9b6618f697ef9a5
# 2022-04-07 10:02:05 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2022-04-07 10:02:05 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2022-04-07 10:02:05 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2022-04-07 10:02:05 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2022-04-07 10:02:05 [scrapy.core.engine] INFO: Spider opened
# 2022-04-07 10:02:05 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2022-04-07 10:02:05 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2022-04-07 10:02:06 [filelock] DEBUG: Attempting to acquire lock 140323454553392 on /Users/skenderi/.cache/python-tldextract/3.8.0.final__py38__3f657d__tldextract-3.2.0/publicsuffix.org-tlds/de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2022-04-07 10:02:06 [filelock] DEBUG: Lock 140323454553392 acquired on /Users/skenderi/.cache/python-tldextract/3.8.0.final__py38__3f657d__tldextract-3.2.0/publicsuffix.org-tlds/de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2022-04-07 10:02:06 [filelock] DEBUG: Attempting to acquire lock 140323454845808 on /Users/skenderi/.cache/python-tldextract/3.8.0.final__py38__3f657d__tldextract-3.2.0/urls/62bf135d1c2f3d4db4228b9ecaf507a2.tldextract.json.lock
# 2022-04-07 10:02:06 [filelock] DEBUG: Lock 140323454845808 acquired on /Users/skenderi/.cache/python-tldextract/3.8.0.final__py38__3f657d__tldextract-3.2.0/urls/62bf135d1c2f3d4db4228b9ecaf507a2.tldextract.json.lock
# 2022-04-07 10:02:06 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): publicsuffix.org:443
# 2022-04-07 10:02:06 [urllib3.connectionpool] DEBUG: https://publicsuffix.org:443 "GET /list/public_suffix_list.dat HTTP/1.1" 200 None
# 2022-04-07 10:02:06 [filelock] DEBUG: Attempting to release lock 140323454845808 on /Users/skenderi/.cache/python-tldextract/3.8.0.final__py38__3f657d__tldextract-3.2.0/urls/62bf135d1c2f3d4db4228b9ecaf507a2.tldextract.json.lock
# 2022-04-07 10:02:06 [filelock] DEBUG: Lock 140323454845808 released on /Users/skenderi/.cache/python-tldextract/3.8.0.final__py38__3f657d__tldextract-3.2.0/urls/62bf135d1c2f3d4db4228b9ecaf507a2.tldextract.json.lock
# 2022-04-07 10:02:06 [filelock] DEBUG: Attempting to release lock 140323454553392 on /Users/skenderi/.cache/python-tldextract/3.8.0.final__py38__3f657d__tldextract-3.2.0/publicsuffix.org-tlds/de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2022-04-07 10:02:06 [filelock] DEBUG: Lock 140323454553392 released on /Users/skenderi/.cache/python-tldextract/3.8.0.final__py38__3f657d__tldextract-3.2.0/publicsuffix.org-tlds/de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2022-04-07 10:02:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=1> (referer: None)
# 2022-04-07 10:02:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=1>
# {'text': "I got the phone, had it shipped all the way  across the world, and guess what! It won't come on! I have tried everything. It won't come on!Returning it is not an option. I would spend the cost of the phone having It shipped back. Just as a warning to others in my condition. DO NOT BUY! You'll be out $100 and with no phone!An update to this review.I spent the weekend googling my Nokia Lumia will not start, and then googled, my Nokia Lumia is stuck on the start-up page and I got excellent help. It seems you need to follow the following steps;Step 1Make sure the power is OFFPress and hold the volume down and connect the charger, if succeed an exclamation mark (!) is down on the screen.Step 2Then input keys in the following orderVolume UpVolume DownPowerVolume downThe screen will then go black.Give the phone about 10 minutes without touching it. Then a set of rotating screws showed on the screen, and then the phone came on.It was a bit of a scare and I am told I must never let the phone's battery die down, because I really do not want to go through that again. But so far, so good for the phone.", 'rating': '3.0 out of 5 stars'}
# 2022-04-07 10:02:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=1>
# {'text': "Got 2nd phone requirements:Didn't want to spend much, have pay as you go T-Mobile planWanted GSM but did not want to be tied into carrier, might user international sim for vacationHave android phone and tablet wanted something different, requirement 1 eliminated AppleGot lightly used 521 from some vender and battery or charging system failed in a day sent it back. Next time got this phone from Amazon Warehouse (I trust this source more than some random vender) this phone worked and has been working for a few months now.App selection is more limited than Android, but I have no special app needs and the games/maps/reference apps on the phone fill my needs.Observations:camera works as well as the Samsung Duos camerawi-fi web browsing is much better than my android feels like a small pc instead of some browser with issues I have to deal with, I have this phone close to me and I use it to lookup things while watching TV or something, feels like a PC but smaller and easier to access.responsiveness, does not lock up by some misbehaving app or downloading updates for all the apps, the operating system in general seems solider android in comparison (maybe because of the apps) seems fragileonce I got use to the scrolling tiles and how to add tiles and size/move tiles I like it as much or more than the android app screens", 'rating': '5.0 out of 5 stars'}
# 2022-04-07 10:02:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=1>
# {'text': "I bought this phone back when I had AT&T's pre-paid plan. I was tired of having a 'cheap' phone that always broke and had no features. I was not into smart phones or having the 'latest and greatest' phone, I just wanted something that worked and didn't look like it was from the 1800's. All my friends run out and buy the newest iPhones and Samsungs like it's the most important thing on the planet. When I take out this cheap phone, everyone is amazed at how fast and snappy the performance is, compared to their $600 iPhone. This phone now pushes the Windows 8.1 update as well.Pros:1. Swipe to text - I can't swipe to text almost as fast as I can type on a keyboard2. GPS - built in with free maps and map updates, threw my old GPS right in the trash, it's accurate and easy to use3. Wi-fi - I get speeds over 20 Mbps on my home router, I can browse the internet without using a data plan via wi-fi as fast as my home computer4. Camera - Only 5 megapixels, but shoots very good and surprisingly steady shots5. Ease of use - this phone is ridiculously intuitive. I find iOS and Android very annoying and 'dumbed down' for someone over the age of 3, all my features are easy to find and quickly customizable.6. Live tiles - again, you can easily customize your 'home screen' to look however you want it to, including transparent tiles with a background image (new to Win 8+)7. Micro SD slot - You can store your music, movies and now apps on your card, saving valuable internal storageCons:1. Battery life - After the Windows 8.1 update my battery life became awful. After a couple hours of heavy use it was almost dead. Come to find out, a lot of apps run in the background. Using the battery saver feature I identified those and restricted their usage. Battery life isn't where it was under Windows 7x, but better than after I first updated.2. Apps - There just aren't as many as there are for iOS and Android. The big ones are there (FB, major banks, etc.) but don't expect to find a lot of the smaller onesAll in all, I'm very pleased with this phone. Considering I didn't get it to enter the smart phone market, it certainly seems to be a winner. It seems very rugged and has stood up well to several drops on the pavement. Updates take forever, by the way, sometimes over an hour. Just be patient. I thought my phone was broken at first.", 'rating': '5.0 out of 5 stars'}
# 2022-04-07 10:02:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=1>
# {'text': "There are too many things wrong to name them all. Obviously the problem relates to Microsoft being incapable of delivering a smart phone that works half as well as most Android devices. Back to the drawing board people.... or just discontinue this. I gave two stars because it works as a phone and WhatsApp works ok.Warning: Do not buy this if it is not being sold from Nokia. I made the mistake of doing this and got what I can only assume is an AT&T clone instead of a Nokia factory direct phone with the result the camera sucks.Where to begin with what is wrong... *sigh*Cons:1. Effectively no expandable storage...what you buy initially is what the phone will use for apps which is where most of your storage inflation comes from and Microsoft does not give you an option to store apps anywhere else so it's basically as if you have no expandable storage...sometimes I think it is still storing videos on the phone memory even though it is supposed to store photos and videos on the card since I installed a micro sd.2. After a while it will refuse to clear temp files...you have to do some kind of crazy fix - go into settings and set the year to 2100 and then you will suddenly have more space free...and yet it still will not clear completely.3. Windows store has precious little useful apps that are free4. No file explorer, seriously!! (Seriously, Microsoft-you did that?)5. Bing - an entire button dedicated to Bing...seriously? Guess what it is what everyone else is used to as the back button so for a while after getting this, I kept making the error and pressing the search engine when I really just wanted to go back.6. Speaking of going back...there does not seem to be that option in the only web browser that comes with this phone: Internet Explorer7. The only browser that comes with this is IE - major flaw...I like options....not restrictions...especially when the restriction is to something that is somewhat inferior to what the alternatives are.8. There's no restart...you have to shut down then start it again.(stay tuned for more...)", 'rating': '2.0 out of 5 stars'}
# 2022-04-07 10:02:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=1>
# {'text': 'Really nice phone for the money. The phone is AT&T branded and came with the telephone version of Windows 10. That is a needlessly clunky operating system for a telephone and although we could cope as we had Windows 10 on our desktop, it is a PITA and thus I give it a 4-star rating. When booting the phone up, the process will attempt to force you into signing up for an AT&T plan, so you must carefully decline all those options in the initial start up phase. Then, however, you will have to sign up with some network to have the phone work. The phone has 1 micro-sized SIM card slot, and we cut down our standard sized SIM from an old phone to a micro size and successfully activated the phone with that card. So far no problems in the USA or in mainland Europe. Battery life is only about 3 days with our very occasional use, but that would be far less if you call more or use the data/internet options, The screen may be small by current standards, but for phone-only use it is fine and the phone fits nicely into small pockets.', 'rating': '4.0 out of 5 stars'}
# 2022-04-07 10:02:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=1>
# {'text': "Summary:Travel to Asia (particularly Taiwan) and need an unlocked GSM phone.Walked into a retail cell service shop that are located everywhere (I went to Far Eastone), sort of like the AT&T or Verizon stores we have in US.Told the sales person I needed a SIM card for phone and internet, he sold me one for $500 NTD which adds additional $100 NTD as rebate.$180 NTD for 1 Gb data usable for 30 days, rest for phone charges, billed per second of usage, expires after 6 months.  Just need your passport and your local drivers license from where ever you live (Any 2 IDs with your photo) for them to make a copy.  They even filled out all the forms required for activation.  Paid cash, so no worries about any possibility of auto debit after I leave.The phone is easy to use.small and thin enough to put in my pants pocket.Win 8 interface is pretty easy to get used to, less learning curve than Android IMO.Less Apps for Win8 compared to Android or iOS, but I'm okay with that.Sound quality is goodwi-fi and 3G signal is pretty good.Battery life easily lasts the whole day, good enough for travel where a phone really is just for map, email, text and occasional calls.I am very happy with the purchase.phone is cheap enough that I don't feel bad about damage or lost.", 'rating': '5.0 out of 5 stars'}
# 2022-04-07 10:02:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=1>
# {'text': 'If I could figure out how to flash this phone and run Android on it, I would.  Windows Phones have some awesome features wrapped in glaring usability issues that made we want to throw this phone in a river. The physical phone itself: nice. I like the camera, the phone feels good in the hand, it\'s got a nice way of handling Micro SD and SIM cards, and all that. Voice quality was fine.But oh...oh...Windows 8.1 what the heck are you doing? So many whizzy features but the basics aren\'t right!A long list of little stuff adds up to big challenges. Stuff like when you can\'t always tap on an address and show it on a map. Or how copy/paste of data from app to app is hit or miss.  This was maddening when I was trying to copy a long conference call dial-in string from an email to the phone.  Can\'t change the "default" Microsoft account in case you start with a personal account and then want to add work - that means that when you send email you have change the "from" address manually, unless you decide to wipe the phone and start over. Over and over again, I ran into all these little problems that I don\'t experience in Android and iOS, I used this phone less than a month and it went into a drawer.', 'rating': '3.0 out of 5 stars'}
# 2022-04-07 10:02:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=1>
# {'text': 'Received this phone in great condition. This phone was unlocked and included headset and charger. Had some Rodgers Wireless (Canadian Cell Provider) apps, ect. which I just deleted. I was able to get this phone to work using Straight Talk\'s AT&T BYOP sim card kit but it wasn\'t easy. The phone and text worked right away but data was difficult and Straight Talk was not helpful! But after joining a Windows Phone forum I was able to find the info I needed. The Hardware is what\'s on review here and Nokia makes a great product! There is no camera flash, but this thing takes amazing low light pictures! Just yesterday I had my first drop off the kitchen table onto a hardwood floor, landed on its corner and it did the typical Nokia thing - back cover flies off, battery falls out, nothing breaks. Re-assemble, boot up and off you go! Really like the screen sensitivity, processing is good for $100 phone. As for the Windows 8.0, I just let it hang out on my WiFi for couple days and it kept installing updates and now I\'m at 8.1 no problem. Here\'s a warning for all you Google users (like me) Windows 8.1 doesn\'t play nice with g-mail or Google calender. I have to check g-mail using my browser, no syncing up unless you want to PAY $5 a mouth for "Google Apps for Business." Why five stars? One word: NOKIA!', 'rating': '5.0 out of 5 stars'}
# 2022-04-07 10:02:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=1>
# {'text': "really like this phone. And I'm very much liking the Windows Phone OS. I've used Android for years, but this is just so clean and solid. Lots of the apps I was using on Android are available on WinPhone OS now, and the Nokia apps like maps and Driving aid are excellent (like you can download maps by state or country to have offline -- makes the data streaming much lighter). Also some new apps just showed up (like Microsoft solitaire) that completed stuff I was looking for. Nokia also has upgraded their suit of apps, and the new camera beta is really powerful. Hard to believe you get all this for such a good price. Did I mention the replaceable battery, or the microSD card slot for storing pictures, videos, and music? Even has an FM radio built in -- not an Internet one (which it can do too), but a real radio, which is just cool. Also saves on data streaming if there's a radio nearby you like to listen to. (BTW, I got an unlocked one because I don't use ATT and I travel to Asia a lot. It was just as advertised. I believe it came from Malaysia as the system languages out-of-the-box were English, Chinese, and Malay. But it is easy to add other system languages to this WinPhone. I did it.", 'rating': '5.0 out of 5 stars'}
# 2022-04-07 10:02:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=1>
# {'text': 'I have been using a top end Google phone for the last three years, and wanted to replace it.  Not wanting to spend much, and also liking the idea of trying another operating system, I decided for this phone.  It is really very nice.  It is pretty fast (faster than my old top end phone which is to be expected even though the specifications are quite similar), and has a decent selection of apps.  It is a little "plasticish", but this is to be expected.  I do like it being light though.  The screen is bright and sharp.  Not having a front facing camera is probably the only real let down, but I know this when paying the phone.  In reality, I have not missed this much as I hardly ever take "selfies", and I can use my laptop for Skype if I want to use video.  The phone did arrive in Chinese!  I had to guess  how to get to the settings screen to change the language to English by looking at the icons. Being registered as coming from Taiwan, it wont allow me to download the original Nokia Music app.  ????  Strange.  I do use a third party app, but it isn\'t quite as slick.', 'rating': '5.0 out of 5 stars'}
# 2022-04-07 10:02:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_2?ie=UTF8&pageNumber=2&reviewerType=all_reviews> (referer: https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=1)
# 2022-04-07 10:02:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_2?ie=UTF8&pageNumber=2&reviewerType=all_reviews>
# {'text': "So first off, most important... it was unlocked!!!  This is a nice phone, something i didn't see too much about in other reviews was the battery, i was concerned about the battery life and it's held a charge very well (although I've only had it over the weekend, I've had to setup and configure the phone the way I want it so it's done well there), it looks and feels great and is pretty fast, basic things like calls are really good, very easy to hear others on the phone and the volume is good too, speakers are better than i expected as well.  Two things that irritate me so far though: the camera button is pretty tough to push and it doesn't give at all so it's difficult to know when you've successfully pressed it until it just snaps the shot; also I could be wrong about this one and I really hope I am but at this point it doesn't appear that you can associate a ringtone to a group... isn't this a smart phone???  I just expect my smart phone should be able to do that but other than those things, this phone is great so far, I would buy from this seller again, phone came on time.", 'rating': '5.0 out of 5 stars'}
# 2022-04-07 10:02:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_2?ie=UTF8&pageNumber=2&reviewerType=all_reviews>
# {'text': "I purchased this phone for international travel, as my current wireless provider does not have good international plans. I've used iPhones for the past five years. I had a Windows phone many years ago and this one is definitely better in terms of usability. I like the layout. It was very easy to figure out. The down side is that the phone loses my WiFi connections every time it's powered down. Apparently, this is a KNOWN ISSUE. It looks like I can fix it by going into my router settings and making some changes. As everything else in my house has no issues connecting wireless with the router, there's no way I'm going to change the settings. I haven't tried the phone on WiFi outside of my house yet to see if it's just an issue with my router or something bigger. Long story short, as long as I don't power down, it remembers its wireless settings. As soon as I shut down, I have to re-enter the router password. This is not a deal-breaker because I'll only be using it a few days a year.", 'rating': '3.0 out of 5 stars'}
# 2022-04-07 10:02:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_2?ie=UTF8&pageNumber=2&reviewerType=all_reviews>
# {'text': "This is my first smartphone ever, and after THAT shiny new elation wore off, I realised it is, as smartphones go, probably not very good. The lack of front-facing camera is a definite downer, and the Bing search button is super annoying if you don't ever, you know, use Bing. Originally I was drawn to the Lumia because of it bragging the best smartphone camera, but while the camera is *good*, it doesn't really compensate for the utterly blah performance--I've had it for only a few months and it already takes a long time to 'resume' from a locked position.I'm not gonna get a windows phone again, I'm pretty sure once I upgrade I'll be trying for the typical galaxy or iphone. I'm super sad about that, because I have been pretty loyally windows my whole life. But this phone is just... not the thing.", 'rating': '2.0 out of 5 stars'}
# 2022-04-07 10:02:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_2?ie=UTF8&pageNumber=2&reviewerType=all_reviews>
# {'text': "I go this phone primarily to use in Europe with in-country accounts or sometimes for domestic travel.  I have another phone for local day to day use.  So,being UNLOCKED was a key issue and after reading some reviews I was concerned.  The phone (which is an ATT instrument) accepted my T-Mobile account with no problem.  I have a relatively cheap pay as you go plan for T-Mobile that I've used with similar unlocked phones for about 6 years now.  It works well with the Nokia 520.  Most of my other devices were Android so I decided to try a Windows phone.  After playing with it for several weeks,  I actually like it better than Android in some ways.  For the money, it was a great deal. Yes there is no flash for the camera and it doesn't have super high resolution.  However, I don't buy a phone to take pictures or a camera to make calls.  I have a good Nikon camera for the picture taking tasks.  So far, I'm happy.  However I noticed several vendors on Amazon selling the same phone for more money.", 'rating': '5.0 out of 5 stars'}
# 2022-04-07 10:02:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_2?ie=UTF8&pageNumber=2&reviewerType=all_reviews>
# {'text': 'I purchased a Nokia Lumia and first received a box that had been previously opened with just a battery pack in it. I was able to get my money refunded and purchase another Lumia (though not in the original color I wanted). After receiving the second phone, the phone seemed to work ok. I was getting used to the layout of the phone. I will say that many of the apps I was using on google play were not available for the windows phone. After slightly over one month of use, I went to grab my phone off of my nightstand and it fell on the carpeted floor. The screen cracked and splintered. The touch screen would not work on the bottom half of the screen. I contacted Amazon about the problem and they told me that I could get it fixed through a 3rd party company (and pay almost the entire cost of the purchased phone). I wasted over one hundred dollars and had to buy a cheap phone from Walmart until I could afford to buy another one. So disappointed.', 'rating': '1.0 out of 5 stars'}
# 2022-04-07 10:02:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_2?ie=UTF8&pageNumber=2&reviewerType=all_reviews>
# {'text': 'I purchased this phone expecting a fairly solid and simple unlocked quadband phone and web browser to take on a vacation abroad (if I ever go on another vacation abroad.)  I have played with it for a week.  The instructions included are poor, but there are a lot of good instructions on the Internet.  The over all impression is that the phone was built and sold so that Microsoft could collect as much personal data about the user as possible. The only possibility for at least semi private browsing is Opera Mini from the Windows Store, which, after trying it out, has itself changed from previous versions to a piece of software that has few instructions even online, and is pretty impossible to use.  Not worth the hours of trouble, either one of them.  The master reset, however works just fine, and I am now bundling it up to give to Goodwill.  Someone with another use for it may find it acceptable.', 'rating': '1.0 out of 5 stars'}
# 2022-04-07 10:02:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_2?ie=UTF8&pageNumber=2&reviewerType=all_reviews>
# {'text': "Bought this as a gift for my GF and so far the phone has not disappointed in the least. Had a bit of trouble getting it fully updated to the latest firmware but it's ok now. Read and watched articles and vids about this phone so as to know all I needed before I gave it to her. What people who read these comments and watch online is that first off this is a BUDGET phone and not a high-end smartphone but a low costing smartphone that doesn't have much internal storage as the apps are stored direct to the phone itself and it has a 5mp shooter that upon hearing such with no flash to boot there should be 0 issues with that.Stop paying under $200 for a smartphone, getting performance like you've spent $2000 and then question why it doesn't do this or do that? No front facing camera, no large internal storage but take those two away and you have the best budget smartphone avl today. I tested everything and they work perfectly, I was pleasantly surprised by that and I am looking forward to the next major update as for the $ spent on this and getting an update that allows the phone to work on par with those that costs 2/3X more you surely/simply cannot go wrong with this purchase.The App store is as it is small in comparison to others but if you want Apps just for the sake of telling your friends and family I have a phone that I can get every single app out there and they work but in reality only use 2 out of the hundreds of thousands then go ahead by my guest. Makes 0 sense dl an app and complaining about it knowing there are many similar apps that a simple uninstall and re-dl of another is a simplistic solution to your gripe.", 'rating': '5.0 out of 5 stars'}
# 2022-04-07 10:02:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_2?ie=UTF8&pageNumber=2&reviewerType=all_reviews>
# {'text': "Were the Lumia 520 on AT&T's subscription service, this phone would be an awful deal. Its low price would soon vanish in higher monthly rates set to subsidize the purchase of pricier hardware. Instead, you can easily get by with a $60/month bill. The camera and battery life could be better, and the mobile-broadband speeds should be faster, but you could do far worse in a starter smartphone.AT&T throws in a few of its own apps. Make the redundant, $9.99-per-month AT&T Navigator the first you uninstall. Unfortunately, the carrier has yet to support Microsoft's Data Sense app, which helps you track your bandwidth usage—a key concern given the limited allocations of most GoPhone plans.Windows Phone 8 handles all of the major audio and video formats except for QuickTime. The 520 also supports one audio format unmentioned in AT&T's spec sheet: FM radio, which is available as long as you have a headphone cable connected to serve as its antenna.", 'rating': '4.0 out of 5 stars'}
# 2022-04-07 10:02:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_2?ie=UTF8&pageNumber=2&reviewerType=all_reviews>
# {'text': "I've had the phone now for over a month. The only remaining issue seems to be something happening with syncing the calendar on this Windows phone to the Hotmail calendar on the internet, and it may very well be a problem at the Hotmail end. Both the phone and computer know what time zone I'm in, but the time for an appointment is two hours off from one device to the other.Sadly, the very reason I bought a Windows phone was to be able to set up appointments with my husband's many medical providers while talking on the phone. That part of it SEEMS to work fine, but since my phone and computer tell me the appointment is at different times, I'm required to remember all the time which device I was using WHEN I set up the appointment so we can get there at the right time. I'm working on this with Microsoft, but it isn't completely resolved yet.", 'rating': '3.0 out of 5 stars'}
# 2022-04-07 10:02:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_2?ie=UTF8&pageNumber=2&reviewerType=all_reviews>
# {'text': "I wasn't used to Windows 8 before getting this, but picked it up quickly.  This phone is a bit bulky, but without a case it's totally fine.  It does not have as many apps, or at least not the original but knockoff apps, as google or apple, but it's manageable.  After having it for a few months now, it is randomly powering off and I have to remove the battery and put it back in to turn it back on, so a bit irritating, but I can deal with it.  One thing I really don't like is the camera. First of all, it does not have a front camera, or at least mine doesn't. It has the place for one, but it isn't hooked up or something because my screen protector came with an opening over the spot that I can see could hold a front camera, but it has no option to use it.  and the back camera is fairly poor quality and also lacks a flash.  Big let down for me, a snapchatter and photo lover, but for some of you, it won't be that big of a deal. Windows also doesn't have snapchat as of now, but hopefully will soon.Pros:Windows 8 (if you like that)Office already on thereSome cool pre-installed apps and featuresGood design for a phoneCons:No front camera, crappy back camera, and no flashNo snapchat, pinterest,or gmail appRandomly shuts off and requires battery removal to power on againAll in all, it's not the best phone in the world, but for the price, it's worth it", 'rating': '3.0 out of 5 stars'}
# 2022-04-07 10:02:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_3?ie=UTF8&pageNumber=3&reviewerType=all_reviews> (referer: https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_2?ie=UTF8&pageNumber=2&reviewerType=all_reviews)
# 2022-04-07 10:02:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_3?ie=UTF8&pageNumber=3&reviewerType=all_reviews>
# {'text': 'Not too many 4 inch display phones out there these days which is why I chose this one. The specs aren\'t stellar by any means but it will run Windows 8.1 (and even a Windows 10 preview I installed). The screen brightness/readability is pretty dismal in bright rooms or sunlight. Feels good in the hand due to the design of the rear shell. My problem with this design though is that if you remove the rear shell enough times it seems to loosen up over time and the shell doesn\'t fit tightly anymore.If like me, you don\'t like the large display phones and simply want a "compact" full featured windows smartphone look into the Lumia 620. Pretty much the same specs as this one but the 620 has a much better display and the camera has a flash. A very solid device.', 'rating': '3.0 out of 5 stars'}
# 2022-04-07 10:02:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_3?ie=UTF8&pageNumber=3&reviewerType=all_reviews>
# {'text': "Looks like I great phone but unfortunately I think I just screwed myself. I was looking for an unlocked cellphone international version with a regular sim card slot to use throughout my visit to South Africa. After all the homework I did throughout amazon I end up purchasing a phone that requires a micro SIM card. Gee now that I know the difference between those two looks like I made a huge mistake. I can't return the phone for the actual one I was hoping for because repackaging few is $35 and ofcourse if I did really read the item explanation perhaps I could have picked it up that this is a micro SIM slot phone still not applicable in countries like the one I'm going to. No problemo. Still is a good phone. I'm an iPhone user so I don't know what I'm gonna do with this one.", 'rating': '4.0 out of 5 stars'}
# 2022-04-07 10:02:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_3?ie=UTF8&pageNumber=3&reviewerType=all_reviews>
# {'text': 'Great phone features most everywhere except the dialing key pad would immediately disappear after establishing connection. This would make menu selection for desired departments almost impossible. Pressing, the power button only brought back the key pad briefly; the time varied. Upgrading to Windows 8,1 helped a little. Nokia does not provide a contact phone number so, as to speak to a live person. You have to take a ticket, fill-out a form and wait. Next time, I will consider the established reliable Motorola brands, first.P.S. Sorry, I first wrote the phone review in the "Dynamic Protective Cover" review block by mistake. Amazon placed the phone image with the protective cover review. Pays to read first; my fault. I could not change it back. The protective cover was good for a "Three Star" rating. The "Dynamic Protective Cover" covered up the bottom thermal sensor on the front. This had to be modified with my Dremel hand tool grinder. You must take the cover off first so, as to work on it!', 'rating': '3.0 out of 5 stars'}
# 2022-04-07 10:02:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_3?ie=UTF8&pageNumber=3&reviewerType=all_reviews>
# {'text': "If you are a windows 8 or 8.1 user you don't have to learn how to use the nokia lumia 520 windows phone. It has a great feel to it and a better camera then my other phone. Great sound and visuals when playing, It can handle small games and listening to music and gaming good. The radio feature great, the package is ok not dents in the boxes or weird smells coming from it. The contents of the items where safe place in it  shipping box. Bing on this phone is much better than my android phone with bing. The windows handle productivity well and web browsing well. The apps are great if you can match then to your lifestyles. Good strong speakers and great camera, Buttons alright. The back case feels a little too easy to put on though. Battery life amazing. End.", 'rating': '5.0 out of 5 stars'}
# 2022-04-07 10:02:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_3?ie=UTF8&pageNumber=3&reviewerType=all_reviews>
# {'text': "This phone is local to India but comes setup in English. It works fine with an AT&T or T-Mobile SIM card. It won't get 4G LTE speeds on those networks and may be limited to Edge, but it works fine and doesn't have to be unlocked to switch carriers. The phone itself is great and a nice value. Camera has no flash and memory is 512 MB so there are a few apps that won't work with it, but over 99% of them will work just fine. I read online that less than 1% of apps require devices with more than 512 MB RAM, so you should be good unless you need a faster, high end phone with a flash and more memory, in that case you might consider a Lumia 925, 928, 920, or 1020 (or some other model that has since come out after I posted this review).", 'rating': '5.0 out of 5 stars'}
# 2022-04-07 10:02:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_3?ie=UTF8&pageNumber=3&reviewerType=all_reviews>
# {'text': "Absolutely love this phone.  It is my first smart phone and didn't want to start off with something expensive in case I didn't like it.  I love the fact that it is not huge, makes it easy to hold.  Feels very durable.  It did come unlocked and works great here in Costa Rica.  Although, they did not ship here, so I had to ship it to a friend in the US and then have them send it to me here.  That is why I gave four stars, the shipping.  Phone works great, no problems, OS is very easy to use.  I am not a very tech savvy person and this was easy to learn how to use.  I have used Nokia phone on and off since my first cell phone back in 2000, always liked them.  My last two cell phones were Nokia and were great.  I have had Motorola and others before, but seem to always go back to Nokia.", 'rating': '4.0 out of 5 stars'}
# 2022-04-07 10:02:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_3?ie=UTF8&pageNumber=3&reviewerType=all_reviews>
# {'text': 'Fast, reliable Lumia phone, great item from this price point, worth the money.I got it from amazon warehouse deals UNLOCKED, not FACTORY UNLOCKED (never had to call AT&T or AMAZON to get any unlocking code for ir, just inserted my MicroSIM card and it worked like a charm, great price, nice phone for its specs (fast despite having only 512MB RAM) comes with windows phone 8.1 on board (lumia 520 RM-915) no problems so far, good signal, smooth user experience with windows phone 8PROS:***GPS works without even inserting the SIM card which is awesome, no internet connection needed.Mine came it all accesories as advertised (be aware this model DOES NOT come with headphones in the sales package, only charger, USB cable, battery and the phone itself)***Windows Phone 8.1 update 1 on board***Speedy, smooth, no crashes (despite having dual core 1.2 Ghz Snapdragon and 512MB RAM) I also have a lumia 930 (Lumia ICON on Verizon) and the OS works almost identical with both, no lacks, no delays, user experience is almost as fast as my lumia 930 which is a flagship device with more specs****SD card support up to 128GB****Built in radio ( no need for internet radio)****Gorilla glass 2 cover****Removable user friendly battery and battery cover****Good size****Screen is LCD with very good viewing angles (almost 170 degress)****16Million color LCD display****Speaker is loud (even louder than the one found in my lumia 930)****5MP autofocus camera***Bluetooth 4.0 & WIFI***Battery life is acceptable all day long with heavy use (two days with average use)CONS:AT&T logo appear at start up and then the Nokia logoNo headphones included in the sales packageNo LED (camera)', 'rating': '5.0 out of 5 stars'}
# 2022-04-07 10:02:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_3?ie=UTF8&pageNumber=3&reviewerType=all_reviews>
# {'text': 'I enjoyed this phone for about 6 months.The phone started to turn off unexpectedly in my pocket and Nokia/microsoft were kind to send me a new battery which did not solve the problem.Then I received a jawbone wristband for christmas and had to return the wristband as there was no app for windows phones.2 months ag , the on/off button started to not reatc well and it s getting worse and worse, I have to remove the back protection to be able to turn it on which is not very practical.I took care of it, never dropped it, had a protective case and screen protection too.I guess the low price should have been a clue.I had this phone for less than a year and will replace it by an android one.', 'rating': '1.0 out of 5 stars'}
# 2022-04-07 10:02:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_3?ie=UTF8&pageNumber=3&reviewerType=all_reviews>
# {'text': 'There\'s no driver from Nokia for Windows for this phone. When I hook it up to USB port to the desktop, it shows asOther devices -> RM-915 | Nokia Lumia 520This means it cannot be used with Zune or "Windows Phone Device Manager".  You can still use "Windows Phone app for desktop" which is limited to copying files to the memory.  I would like to be able to manage apps from the PC, similar to iTunes and iPhone since typing on real keyboard and a mouse with big screen is easier for me than doing it on the phone itself.Other than that phone is great for the price. It is fast, looks modern, thinner than the iPhone 5 (my main phone)  and overall it is OK for the money.  Nokia doesn\'t support it with it\'s studio, so it looks like it has been crippled by purpose - otherwise it would compete with more expensive models. This phone begs for 3rd party support, primarily to manage apps on the phone, since it looks Nokia will not provide any additional support.', 'rating': '3.0 out of 5 stars'}
# 2022-04-07 10:02:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_3?ie=UTF8&pageNumber=3&reviewerType=all_reviews>
# ...
# 2022-04-07 10:03:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_158?ie=UTF8&pageNumber=158&reviewerType=all_reviews>
# {'text': 'Does it work in indonesia network GSM??', 'rating': '5.0 out of 5 stars'}
# 2022-04-07 10:03:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_158?ie=UTF8&pageNumber=158&reviewerType=all_reviews>
# {'text': 'nice and looking good I will recomande to my friend', 'rating': '5.0 out of 5 stars'}
# 2022-04-07 10:03:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_158?ie=UTF8&pageNumber=158&reviewerType=all_reviews>
# {'text': 'super exelente', 'rating': '5.0 out of 5 stars'}
# 2022-04-07 10:03:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_158?ie=UTF8&pageNumber=158&reviewerType=all_reviews>
# {'text': 'this link can get you free stuff even this nokia lumia', 'rating': '5.0 out of 5 stars'}
# 2022-04-07 10:03:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_158?ie=UTF8&pageNumber=158&reviewerType=all_reviews>
# {'text': 'EXCELENT PHONE. VERY RECOMENDED', 'rating': '5.0 out of 5 stars'}
# 2022-04-07 10:03:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_158?ie=UTF8&pageNumber=158&reviewerType=all_reviews>
# {'text': 'This phone i like it because is fast and complete', 'rating': '4.0 out of 5 stars'}
# 2022-04-07 10:03:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_159?ie=UTF8&pageNumber=159&reviewerType=all_reviews> (referer: https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_158?ie=UTF8&pageNumber=158&reviewerType=all_reviews)
# 2022-04-07 10:03:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_159?ie=UTF8&pageNumber=159&reviewerType=all_reviews>
# {'text': 'I bought this for my sister and she liked it. Good one.', 'rating': '4.0 out of 5 stars'}
# 2022-04-07 10:03:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_159?ie=UTF8&pageNumber=159&reviewerType=all_reviews>
# {'text': 'Would not charge up.  Had to return.', 'rating': '1.0 out of 5 stars'}
# 2022-04-07 10:03:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_159?ie=UTF8&pageNumber=159&reviewerType=all_reviews>
# {'text': 'Sweet device', 'rating': '4.0 out of 5 stars'}
# 2022-04-07 10:03:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_159?ie=UTF8&pageNumber=159&reviewerType=all_reviews>
# {'text': 'Can I use simcard in philippines', 'rating': '5.0 out of 5 stars'}
# 2022-04-07 10:03:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_159?ie=UTF8&pageNumber=159&reviewerType=all_reviews>
# {'text': 'Love it', 'rating': '5.0 out of 5 stars'}
# 2022-04-07 10:03:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_159?ie=UTF8&pageNumber=159&reviewerType=all_reviews>
# {'text': 'Nice phone.. amazing features. . Love the tiles..', 'rating': '4.0 out of 5 stars'}
# 2022-04-07 10:03:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_159?ie=UTF8&pageNumber=159&reviewerType=all_reviews>
# {'text': 'excelente producto', 'rating': '5.0 out of 5 stars'}
# 2022-04-07 10:03:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_159?ie=UTF8&pageNumber=159&reviewerType=all_reviews>
# {'text': 'Excellent, unlocked phone', 'rating': '5.0 out of 5 stars'}
# 2022-04-07 10:03:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_159?ie=UTF8&pageNumber=159&reviewerType=all_reviews>
# {'text': 'Amazing phone for 75 bucks', 'rating': '5.0 out of 5 stars'}
# 2022-04-07 10:03:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_159?ie=UTF8&pageNumber=159&reviewerType=all_reviews>
# {'text': 'buenisimo', 'rating': '5.0 out of 5 stars'}
# 2022-04-07 10:03:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_160?ie=UTF8&pageNumber=160&reviewerType=all_reviews> (referer: https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_159?ie=UTF8&pageNumber=159&reviewerType=all_reviews)
# 2022-04-07 10:03:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_160?ie=UTF8&pageNumber=160&reviewerType=all_reviews>
# {'text': 'Very good', 'rating': '5.0 out of 5 stars'}
# 2022-04-07 10:03:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_160?ie=UTF8&pageNumber=160&reviewerType=all_reviews>
# {'text': 'excelente', 'rating': '5.0 out of 5 stars'}
# 2022-04-07 10:03:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_160?ie=UTF8&pageNumber=160&reviewerType=all_reviews>
# {'text': 'This product had a crack on the camara lens not mentioned before sale', 'rating': '1.0 out of 5 stars'}
# 2022-04-07 10:03:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_160?ie=UTF8&pageNumber=160&reviewerType=all_reviews>
# {'text': 'Good', 'rating': '5.0 out of 5 stars'}
# 2022-04-07 10:03:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_160?ie=UTF8&pageNumber=160&reviewerType=all_reviews>
# {'text': 'Perfect', 'rating': '5.0 out of 5 stars'}
# 2022-04-07 10:03:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_160?ie=UTF8&pageNumber=160&reviewerType=all_reviews>
# {'text': 'Does this work for GCI?', 'rating': '5.0 out of 5 stars'}
# 2022-04-07 10:03:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_160?ie=UTF8&pageNumber=160&reviewerType=all_reviews>
# {'text': 'very good', 'rating': '5.0 out of 5 stars'}
# 2022-04-07 10:03:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_160?ie=UTF8&pageNumber=160&reviewerType=all_reviews>
# {'text': 'works 3g in 900 mhz band? i wont it to digitel tim gsm venezuela and thats the 3g band thanks', 'rating': '3.0 out of 5 stars'}
# 2022-04-07 10:03:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_160?ie=UTF8&pageNumber=160&reviewerType=all_reviews>
# {'text': 'does it go with verizon?', 'rating': '3.0 out of 5 stars'}
# 2022-04-07 10:03:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_160?ie=UTF8&pageNumber=160&reviewerType=all_reviews>
# {'text': 'This phone is a piece of crap. It has a smooth running spftware but its the worst if ur a gamer or someone who used to own an android or ios. WINDOWS STORE BARELY HAS ANY APPS, WORTHLESS AND USELESS', 'rating': '1.0 out of 5 stars'}
# 2022-04-07 10:03:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_161?ie=UTF8&pageNumber=161&reviewerType=all_reviews> (referer: https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_160?ie=UTF8&pageNumber=160&reviewerType=all_reviews)
# 2022-04-07 10:03:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_161?ie=UTF8&pageNumber=161&reviewerType=all_reviews>
# {'text': 'Guuuau....very good.', 'rating': '5.0 out of 5 stars'}
# 2022-04-07 10:03:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_161?ie=UTF8&pageNumber=161&reviewerType=all_reviews>
# {'text': "didn't like it", 'rating': '1.0 out of 5 stars'}
# 2022-04-07 10:03:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_161?ie=UTF8&pageNumber=161&reviewerType=all_reviews>
# {'text': 'Its a new article?', 'rating': '1.0 out of 5 stars'}
# 2022-04-07 10:03:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_161?ie=UTF8&pageNumber=161&reviewerType=all_reviews>
# {'text': 'I was foolish enough to order this Lumina 520 and was told directly on several occasions (calls to Microsoft and to sellers) that this phone was unlocked.  NOT SO.This is a GO-PHONE and can only be used on AT&T network.  So BE CAREFUL.  When Amazon says "unlocked" you are not receiving accurate information.  UNLOCKED means "no contract" and you can put YOUR OWN SIM in.  I fear that many of the so-called "unlocked phones" on amazon are limited to a specific network.And NEVER buy anything from MICROSOFT; the service is dreadful and the so-called technical "help" is staffed by people who do not know what they are doing.H', 'rating': '1.0 out of 5 stars'}
# 2022-04-07 10:03:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_161?ie=UTF8&pageNumber=161&reviewerType=all_reviews>
# {'text': 'excelente', 'rating': '5.0 out of 5 stars'}
# 2022-04-07 10:03:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_161?ie=UTF8&pageNumber=161&reviewerType=all_reviews>
# {'text': "It was the cell phone with the best performance and for a competitive price, it's a shame that the operating system was abandoned...", 'rating': '5.0 out of 5 stars'}
# 2022-04-07 10:03:45 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_161?ie=UTF8&pageNumber=161&reviewerType=all_reviews> (referer: https://www.amazon.com/Nokia-520-Unlocked-Dual-Core-Smartphone/product-reviews/B00D7OOAHA/ref=cm_cr_arp_d_paging_btm_160?ie=UTF8&pageNumber=160&reviewerType=all_reviews)
# Traceback (most recent call last):
#   File "/Users/skenderi/miniconda/miniconda3/envs/py38/lib/python3.8/site-packages/scrapy/utils/defer.py", line 132, in iter_errback
#     yield next(it)
#   File "/Users/skenderi/miniconda/miniconda3/envs/py38/lib/python3.8/site-packages/scrapy/utils/python.py", line 354, in __next__
#     return next(self.data)
#   File "/Users/skenderi/miniconda/miniconda3/envs/py38/lib/python3.8/site-packages/scrapy/utils/python.py", line 354, in __next__
#     return next(self.data)
#   File "/Users/skenderi/miniconda/miniconda3/envs/py38/lib/python3.8/site-packages/scrapy/core/spidermw.py", line 66, in _evaluate_iterable
#     for r in iterable:
#   File "/Users/skenderi/miniconda/miniconda3/envs/py38/lib/python3.8/site-packages/scrapy/spidermiddlewares/offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "/Users/skenderi/miniconda/miniconda3/envs/py38/lib/python3.8/site-packages/scrapy/core/spidermw.py", line 66, in _evaluate_iterable
#     for r in iterable:
#   File "/Users/skenderi/miniconda/miniconda3/envs/py38/lib/python3.8/site-packages/scrapy/spidermiddlewares/referer.py", line 342, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/Users/skenderi/miniconda/miniconda3/envs/py38/lib/python3.8/site-packages/scrapy/core/spidermw.py", line 66, in _evaluate_iterable
#     for r in iterable:
#   File "/Users/skenderi/miniconda/miniconda3/envs/py38/lib/python3.8/site-packages/scrapy/spidermiddlewares/urllength.py", line 40, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/Users/skenderi/miniconda/miniconda3/envs/py38/lib/python3.8/site-packages/scrapy/core/spidermw.py", line 66, in _evaluate_iterable
#     for r in iterable:
#   File "/Users/skenderi/miniconda/miniconda3/envs/py38/lib/python3.8/site-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/Users/skenderi/miniconda/miniconda3/envs/py38/lib/python3.8/site-packages/scrapy/core/spidermw.py", line 66, in _evaluate_iterable
#     for r in iterable:
#   File "/Users/skenderi/Documents/GitHub/joda2022/koodiesimerkit/amazon_scraper.py", line 20, in parse
#     'rating': review_ratings[i]
# IndexError: list index out of range
# 2022-04-07 10:03:45 [scrapy.core.engine] INFO: Closing spider (finished)
# 2022-04-07 10:03:45 [scrapy.extensions.feedexport] INFO: Stored json feed (1606 items) in: out.json
# 2022-04-07 10:03:45 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 152528,
#  'downloader/request_count': 161,
#  'downloader/request_method_count/GET': 161,
#  'downloader/response_bytes': 13737796,
#  'downloader/response_count': 161,
#  'downloader/response_status_count/200': 161,
#  'elapsed_time_seconds': 99.651321,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2022, 4, 7, 7, 3, 45, 313844),
#  'httpcompression/response_bytes': 50691157,
#  'httpcompression/response_count': 161,
#  'item_scraped_count': 1606,
#  'log_count/DEBUG': 1778,
#  'log_count/ERROR': 1,
#  'log_count/INFO': 12,
#  'memusage/max': 536707072,
#  'memusage/startup': 266862592,
#  'request_depth_max': 160,
#  'response_received_count': 161,
#  'scheduler/dequeued': 161,
#  'scheduler/dequeued/memory': 161,
#  'scheduler/enqueued': 161,
#  'scheduler/enqueued/memory': 161,
#  'spider_exceptions/IndexError': 1,
#  'start_time': datetime.datetime(2022, 4, 7, 7, 2, 5, 662523)}
# 2022-04-07 10:03:45 [scrapy.core.engine] INFO: Spider closed (finished)
